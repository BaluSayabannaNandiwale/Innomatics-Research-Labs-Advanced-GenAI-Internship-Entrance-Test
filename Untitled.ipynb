# %%
import pandas as pd
import sqlite3
import json

# %%
orders_df = pd.read_csv("orders.csv")
orders_df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                   restaurant_name
# 0               New Foods Chinese
# 1  Ruchi Curry House Multicuisine
# 2           Spice Kitchen Punjabi
# 3          Darbar Kitchen Non-Veg
# 4       Royal Eatery South Indian

# %%
with open("users.json", "r") as f:
    users_data = json.load(f)

users_df = pd.DataFrame(users_data)
users_df.head()
# Out:
#    user_id    name       city membership
# 0        1  User_1    Chennai    Regular
# 1        2  User_2       Pune       Gold
# 2        3  User_3  Bangalore       Gold
# 3        4  User_4  Bangalore    Regular
# 4        5  User_5       Pune       Gold

# %%
# Create in-memory SQLite database
conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

# Execute SQL script
with open("restaurants.sql", "r") as f:
    sql_script = f.read()

cursor.executescript(sql_script)

# Load restaurants table
restaurants_df = pd.read_sql("SELECT * FROM restaurants", conn)
restaurants_df.head()
# Out:
#    restaurant_id restaurant_name  cuisine  rating
# 0              1    Restaurant_1  Chinese     4.8
# 1              2    Restaurant_2   Indian     4.1
# 2              3    Restaurant_3  Mexican     4.3
# 3              4    Restaurant_4  Chinese     4.1
# 4              5    Restaurant_5  Chinese     4.8

# %%
# Orders + Users
merged_df = orders_df.merge(
    users_df,
    how="left",
    on="user_id"
)

# Orders + Restaurants
final_df = merged_df.merge(
    restaurants_df,
    how="left",
    on="restaurant_id"
)

final_df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                 restaurant_name_x       name       city membership  \
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular
#
#   restaurant_name_y  cuisine  rating
# 0    Restaurant_450  Mexican     3.2
# 1    Restaurant_309   Indian     4.5
# 2    Restaurant_107  Mexican     4.0
# ...

# %%
final_df.to_csv("final_food_delivery_dataset.csv", index=False)
print("✅ final_food_delivery_dataset.csv created")
# Out:
# ✅ final_food_delivery_dataset.csv created

# %%
final_df[final_df["membership"] == "Gold"] \
    .groupby("city")["total_amount"] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# city
# Chennai      1080909.79
# Pune         1003012.32
# Bangalore     994702.59
# Hyderabad     896740.19
# Name: total_amount, dtype: float64

# %%
final_df.groupby("cuisine")["total_amount"] \
    .mean() \
    .sort_values(ascending=False)
# Out:
# cuisine
# Mexican    808.021344
# Italian    799.448578
# Indian     798.466011
# Chinese    798.389020
# Name: total_amount, dtype: float64

# %%
user_spending = final_df.groupby("user_id")["total_amount"].sum()
(user_spending > 1000).sum()
# Out:
# 2544

# %%
bins = [3.0, 3.5, 4.0, 4.5, 5.0]
labels = ["3.0–3.5", "3.6–4.0", "4.1–4.5", "4.6–5.0"]

final_df["rating_range"] = pd.cut(
    final_df["rating"],
    bins=bins,
    labels=labels,
    include_lowest=True
)

final_df.groupby("rating_range")["total_amount"] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# C:\Users\nandi\AppData\Local\Temp\ipykernel_12500\2176379850.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   final_df.groupby("rating_range")["total_amount"] \
# rating_range
# 4.6–5.0    2197030.75
# 3.0–3.5    2136772.70
# 4.1–4.5    1960326.26
# 3.6–4.0    1717494.41
# Name: total_amount, dtype: float64

# %%
final_df[final_df["membership"] == "Gold"] \
    .groupby("city")["total_amount"] \
    .mean() \
    .sort_values(ascending=False)
# Out:
# city
# Chennai      808.459080
# Hyderabad    806.421034
# Bangalore    793.223756
# Pune         781.162243
# Name: total_amount, dtype: float64

# %%
final_df.groupby("cuisine").agg(
    restaurant_count=("restaurant_id", "nunique"),
    revenue=("total_amount", "sum")
).sort_values(
    ["restaurant_count", "revenue"],
    ascending=[True, False]
)
# Out:
#          restaurant_count     revenue
# cuisine
# Chinese               120  1930504.65
# Italian               126  2024203.80
# Indian                126  1971412.58
# Mexican               128  2085503.09

# %%
gold_percentage = (
    final_df[final_df["membership"] == "Gold"].shape[0]
    / final_df.shape[0]
) * 100

round(gold_percentage)
# Out:
# 50

# %%
# Highest AOV Restaurant with < 20 Orders
restaurant_stats = final_df.groupby("restaurant_name").agg(
    order_count=("order_id", "count"),
    avg_order_value=("total_amount", "mean")
)

restaurant_stats[restaurant_stats["order_count"] < 20] \
    .sort_values("avg_order_value", ascending=False)
# Out:
#                  order_count  avg_order_value
# restaurant_name
# User_2429                  1          1497.42
# User_889                   1          1492.63
# User_1843                  1          1484.24
# User_1882                  1          1481.84
# User_925                   1          1476.18
# ...                      ...              ...
# User_2368                  1           119.08
# User_2583                  1           117.62
# User_1188                  1           109.58
# User_1520                  1           106.62
# User_1880                  1           102.22
#
# [2883 rows x 2 columns]

# %%
final_df.groupby(["membership", "cuisine"])["total_amount"] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# membership  cuisine
# Regular     Mexican    1072943.30
#             Italian    1018424.75
# Gold        Mexican    1012559.79
#             Italian    1005779.05
# Regular     Indian      992100.27
# Gold        Indian      979312.31
#             Chinese     977713.74
# Regular     Chinese     952790.91
# Name: total_amount, dtype: float64

# %%
final_df["order_date"] = pd.to_datetime(final_df["order_date"])
final_df["quarter"] = final_df["order_date"].dt.to_period("Q")

final_df.groupby("quarter")["total_amount"] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# C:\Users\nandi\AppData\Local\Temp\ipykernel_12500\3064641765.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   final_df["order_date"] = pd.to_datetime(final_df["order_date"])
# quarter
# 2023Q3    2037385.10
# 2023Q4    2018263.66
# 2023Q1    1993425.14
# 2023Q2    1945348.72
# 2024Q1      17201.50
# Freq: Q-DEC, Name: total_amount, dtype: float64

# %%
final_df = final_df.rename(columns={
    "name": "restaurant_name"
})
restaurant_stats = final_df.groupby("restaurant_name").agg(
    order_count=("order_id", "count"),
    avg_order_value=("total_amount", "mean")
)

restaurant_stats[restaurant_stats["order_count"] < 20] \
    .sort_values("avg_order_value", ascending=False)
# Out:
#                  order_count  avg_order_value
# restaurant_name
# User_2429                  1          1497.42
# User_889                   1          1492.63
# User_1843                  1          1484.24
# User_1882                  1          1481.84
# User_925                   1          1476.18
# ...                      ...              ...
# User_2368                  1           119.08
# User_2583                  1           117.62
# User_1188                  1           109.58
# User_1520                  1           106.62
# User_1880                  1           102.22
#
# [2883 rows x 2 columns]

# %%
#Q1. How many total orders were placed by users with Gold membership?
final_df[final_df["membership"] == "Gold"].shape[0]
# Out:
# 4987

# %%
#Q2. Total revenue (rounded) from orders placed in Hyderabad
round(
    final_df[final_df["city"] == "Hyderabad"]["total_amount"].sum()
)
# Out:
# 1889367

# %%
#Q3. How many distinct users placed at least one order?
final_df["user_id"].nunique()
# Out:
# 2883

# %%
#Q4. Average order value (rounded to 2 decimals) for Gold members
round(
    final_df[final_df["membership"] == "Gold"]["total_amount"].mean(),
    2
)
# Out:
# 797.15

# %%
#Q5. How many orders were placed for restaurants with rating ≥ 4.5?
final_df[final_df["rating"] >= 4.5].shape[0]
# Out:
# 3374

# %%
#Q6. How many orders were placed in the top revenue city among Gold members only?

# %%
top_gold_city = (
    final_df[final_df["membership"] == "Gold"]
    .groupby("city")["total_amount"]
    .sum()
    .idxmax()
)

top_gold_city
# Out:
# 'Chennai'

# %%
final_df[
    (final_df["membership"] == "Gold") &
    (final_df["city"] == top_gold_city)
].shape[0]
# Out:
# 1337

# %%
#Column used to join orders.csv and users.json
# Inspect common columns
set(orders_df.columns).intersection(set(users_df.columns))
# Out:
# {'user_id'}

# %%
# The dataset containing cuisine and rating information is stored in
# ➡ SQL format
# Restaurants data source
type(restaurants_df)
# Out:
# pandas.core.frame.DataFrame

# %%
final_df.shape[0], orders_df.shape[0]
# Out:
# (10000, 10000)

# %%
final_df[final_df["membership"].isna()].head()
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, restaurant_id, order_date, total_amount, restaurant_name_x, restaurant_name, city, membership, restaurant_name_y, cuisine, rating, rating_range, quarter]
# Index: []

# %%
# Example merge used
orders_df.merge(users_df, how="left", on="user_id").head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                   restaurant_name       name       city membership
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular

# %%
"membership" in users_df.columns, "membership" in orders_df.columns
# Out:
# (True, False)

# %%
set(orders_df.columns).intersection(set(restaurants_df.columns))
# Out:
# {'restaurant_id', 'restaurant_name'}

# %%
restaurants_df[["restaurant_id", "cuisine"]].head()
# Out:
#    restaurant_id  cuisine
# 0              1  Chinese
# 1              2   Indian
# 2              3  Mexican
# 3              4  Chinese
# 4              5  Chinese
